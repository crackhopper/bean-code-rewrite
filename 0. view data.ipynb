# %%
# %pylab inline
data_dir = './data/'
f_ggood = data_dir + 'green_good.txt'
f_gspoil = data_dir + 'green_spoil.txt'
f_rgood = data_dir + 'red_good.txt'
f_rspoil = data_dir + 'red_spoil.txt'
f_gold = data_dir + 'green_old.txt'
f_gwater = data_dir + 'green_water.txt'
f_rold = data_dir + 'red_old.txt'
f_rwater = data_dir + 'red_water.txt'

fs_green = [f_ggood, f_gspoil, f_gold, f_gwater]
fs_red = [f_rgood, f_rspoil, f_rold, f_rwater]
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
from utils import readBeanData, makeRGB
arr_rgood = readBeanData(f_rgood)

# %%
img_rgood = makeRGB(arr_rgood)
imshow(img_rgood)

# %%
imsave('./output/img_rgood.jpg', img_rgood)
